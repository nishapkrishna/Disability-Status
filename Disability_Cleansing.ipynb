# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import os
import csv

# %%
# File to Load (Remember to Change These)
file_to_load = "Resources/Disability_Status_Data.csv"

# Read Purchasing File and store into Pandas data frame
Disability_data = pd.read_csv(file_to_load)

# %%
Disability_data.head()
# Out:
#    Year LocationAbbr  LocationDesc DataSource              Category  \
# 0  2017           TN     Tennessee      BRFSS  Disability Estimates
# 1  2017           NY      New York      BRFSS  Disability Estimates
# 2  2017           MI      Michigan      BRFSS  Disability Estimates
# 3  2017           IN       Indiana      BRFSS  Disability Estimates
# 4  2017         HHS1  HHS Region 1      BRFSS  Disability Estimates
#
#                                            Indicator  \
# 0  Disability status and types among adults 18 ye...
# 1  Disability status and types among adults 18 ye...
# 2  Disability status and types among adults 18 ye...
# 3  Disability status and types among adults 18 ye...
# 4  Disability status and types among adults 18 ye...
#
#                         Response Data_Value_Unit          Data_Value_Type  \
# 0                  No Disability               %  Age-adjusted Prevalence
# 1  Independent Living Disability               %  Age-adjusted Prevalence
# ...

# %%
Disability_data.columns
# Out:
# Index(['Year', 'LocationAbbr', 'LocationDesc', 'DataSource', 'Category',
#        'Indicator', 'Response', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'Number', 'WeightedNumber', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategory2', 'Stratification2',
#        'CategoryID', 'IndicatorID', 'Geolocation', 'LocationID', 'ResponseID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2'],
#       dtype='object')

# %%
# Extract 'Year', 'LocationAbbr', 'LocationDesc', 'DataSource', 'Category',
#       'Indicator', 'Response','Data_Value_Type',
#       'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#       'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit',
#       'Number', 'WeightedNumber', 'StratificationCategory1',
#       'Stratification1', 'StratificationCategory2', 'Stratification2',
#       'CategoryID', 'IndicatorID', 'Geolocation', 'LocationID', 'ResponseID',
#       'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1'

Disability_data_df = Disability_data.loc[:, ["Year", "LocationAbbr", "LocationDesc",
                                    "DataSource", "Category", "Indicator", "Response", "Data_Value_Type",
                                   "Data_Value","Data_Value_Alt","Data_Value_Footnote_Symbol","Data_Value_Footnote",
                                   "Low_Confidence_Limit","High_Confidence_Limit","Number","WeightedNumber","StratificationCategory1",
                                   "Stratification1","StratificationCategory2","Stratification2",
                                   "CategoryID","IndicatorID","Geolocation","LocationID","ResponseID",
                                   "DataValueTypeID","StratificationCategoryID1","StratificationID1"]]
Disability_data_df.head()
# Out:
#    Year LocationAbbr  LocationDesc DataSource              Category  \
# 0  2017           TN     Tennessee      BRFSS  Disability Estimates
# 1  2017           NY      New York      BRFSS  Disability Estimates
# 2  2017           MI      Michigan      BRFSS  Disability Estimates
# 3  2017           IN       Indiana      BRFSS  Disability Estimates
# 4  2017         HHS1  HHS Region 1      BRFSS  Disability Estimates
#
#                                            Indicator  \
# 0  Disability status and types among adults 18 ye...
# 1  Disability status and types among adults 18 ye...
# 2  Disability status and types among adults 18 ye...
# 3  Disability status and types among adults 18 ye...
# 4  Disability status and types among adults 18 ye...
#
#                         Response          Data_Value_Type  Data_Value  \
# 0                  No Disability  Age-adjusted Prevalence        70.5
# 1  Independent Living Disability  Age-adjusted Prevalence         5.9
# ...

# %%
# Specify the file to write to
output_path = os.path.join("..", "output", "new.csv")

# %%
export_csv = Disability_data_df.to_csv ('Resources\Disability_data_df.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
